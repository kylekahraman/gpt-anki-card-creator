# %%
import csv
import pandas as pd
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")

client = OpenAI(api_key=api_key)

csv_path = "/Users/kyle/GitHub/gpt-anki-card-creator/anki-add.csv"

df = pd.read_csv(csv_path, header=None, names=["Question", "Answer"])

content_string = "\n\n".join(
    f"Q: {q}\nA: {a}" for q, a in zip(df["Question"], df["Answer"])
)

# %%
system_prompt = """
You are an assistant tasked with removing duplicate questions from a set of flashcards. Each flashcard contains a question (labeled "Q:") and an answer (labeled "A:"). The questions can be formulated differently, but ultimately the contents asked should not be there more than once. The answers can be identical or not.

Instructions:
1. Review each question and identify any duplicates.
2. For any duplicate questions, keep only the first instance and remove the others. Do not alter the content or structure of non-duplicate flashcards.
3. Provide the output in the same format, with each question and answer pair clearly separated.
"""

user_prompt = """
Hey, I have a set of flashcard question and answer pairs and need you to find the duplicates. They can be formulated differently. Please delete those that ask the same contents. Think wise, I am tired.
Flashcards:
{file_contents}
"""


def remove_duplicates(file_contents, system_prompt, user_prompt):
    system_prompt = system_prompt.format(file_contents=file_contents)
    user_prompt = user_prompt.format(file_contents=file_contents)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        temperature=0,
        max_tokens=16384,
    )

    cleaned_flashcards = response.choices[0].message.content
    return cleaned_flashcards


cleaned_flashcards = remove_duplicates(content_string, system_prompt, user_prompt)
print(cleaned_flashcards)
# Out:
# Here is the revised set of flashcards with duplicates removed:
#
# Q: What are the main structures derived from each of the three primary brain vesicles?
# A: Prosencephalon, Mesencephalon, and Rhombencephalon lead to various brain structures.
#
# Q: What is the significance of understanding normal brain anatomy in the context of neuroscience?
# A: It provides a necessary basis to understand diseases.
#
# Q: What is the significance of fiber tracts in brain communication?
# A: They facilitate the rapid transmission of information between brain regions.
#
# Q: What are the major divisions of the human nervous system?
# A: Central nervous system (CNS) and peripheral nervous system (PNS).
#
# Q: What are neural tube defects and their common forms?
# A: Defects such as Anencephalus and Spina bifida due to failure of closure.
#
# Q: How does the structure of the spinal cord change during growth?
# A: The spinal cord doesn't grow as fast as the spine, leading to elongation of rootlets.
#
# Q: What types of fibers are included in spinal and cranial nerves?
# A: Motor fibers from ventral rootlets and sensory fibers from dorsal rootlets.
#
# Q: What is the function of the arachnoid layer of the meninges?
# A: It covers the brain and contains subarachnoid space with cerebrospinal fluid (CSF).
#
# Q: What are the layers of the brain and their functions?
# A: The brain has gray matter (processing) and white matter (communication).
#
# Q: How does cerebrospinal fluid (CSF) interact with the brain's protective layers?
# A: It is contained within the subarachnoid space and helps cushion the brain.
#
# Q: What role do neural crest cells play in the development of the peripheral nervous system?
# A: They migrate to form structures like autonomic ganglia and dorsal root ganglia.
#
# Q: How is cerebrospinal fluid produced and absorbed in the brain?
# A: Produced in the ventricles and absorbed via arachnoid granules.
#
# Q: What are the three parts of the human brain?
# A: Telencephalon, Diencephalon, and Brain Stem.
#
# Q: What techniques are used to visualize brain structures in neuroanatomy?
# A: MRI and sectional imaging techniques for 3D reconstruction.
#
# Q: How is the spinal cord organized in terms of its regional segments?
# A: It is divided into cervical, thoracic, lumbar, sacral, and coccygeal segments.
#
# Q: How does the development of the neural tube occur during embryogenesis?
# A: The neural tube forms in the 3rd and 4th week of development.
#
# Q: What is the significance of sulci and gyri dynamics in brain structure?
# A: They provide surface area for neurons and separate functional areas.
#
# Q: What are the layers of meninges surrounding the brain?
# A: Dura mater, Arachnoid, and Pia mater.
#
# Q: How do cortical and subcortical structures connect within the brain?
# A: Via commissures and fiber tracts allowing communication between regions.
#
# Q: How does the spinal cord differ in structure from the brain?
# A: The spinal cord is segmented and does not have the same complexity of folds as the brain.
#
# Q: How do brain injuries affect specific areas and functions of the brain?
# A: Injuries can lead to specific deficits based on the affected brain area.
#
# Q: What are the clinical implications of the different types of meningitis?
# A: Meningitis can cause inflammation and increased intracranial pressure.
#
# Q: What are the primary components of the central nervous system?
# A: The brain and spinal cord.
#
# Q: What are the key functional areas of the cerebral cortex?
# A: Areas involved in sensory, motor, and higher cognitive functions.
#
# Q: What are the characteristics and functions of the telencephalon?
# A: It is the largest part of the brain, involved in higher functions such as reasoning.
#
# Q: What is the primary role of the dura mater?
# A: To stabilize the brain and subdivide spaces inside the skull.
#
# Q: What sections of the brain are typically covered in neuroanatomy lectures?
# A: Development, spinal cord, surface anatomy, sections of the brain, brain stem, cerebellum, and fiber tracts.
#
# Q: What conditions are associated with elevated intracranial pressure?
# A: Traumatic hemorrhages, meningitis, and tumors.
#
# Q: What are the consequences of spinal cord injuries?
# A: They can lead to loss of function and sensation depending on the injury level.
#
# Q: What are the main lobes of the brain, and what are their general functions?
# A: Frontal (thinking), Parietal (sensation), Occipital (vision), and Temporal (hearing).
#
# Q: What is the primary function of motor neurons?
# A: Motor neurons transmit information from the brain to the body.
#
# Q: Where are the cell bodies of motor neurons typically located?
# A: The cell bodies of motor neurons can be located at various levels in the spinal cord.
#
# Q: How do sensory neurons transmit information?
# A: Sensory neurons collect information from the periphery and transmit it to the spinal cord or brain.
#
# Q: What is the structural characteristic of motor neurons?
# A: Motor neurons are typically multipolar, characterized by multiple dendrites and long axons.
#
# Q: What type of neurons are sensory neurons and how are they structured?
# A: Sensory neurons are pseudo-unipolar, with a single neurite that bifurcates.
#
# Q: What is the role of the dorsal root ganglion?
# A: The dorsal root ganglion contains sensory neuron cell bodies.
#
# Q: How does motor information exit the spinal cord?
# A: Motor information exits through the ventral horn and root.
#
# Q: What is the function of the lateral horn in the spinal cord?
# A: The lateral horn contains sympathetic neurons (pre-ganglionic) that project to autonomic ganglia or directly to target organs.
#
# Q: What are the three fiber tracts found in the spinal cord's white matter?
# A: The three fiber tracts are the ventral column (efferent motor neurons), dorsal column (afferent sensory fibers), and lateral column (corticospinal tracts).
#
# Q: From what embryonic layer does neural tissue develop?
# A: Neural tissue develops from the ectoderm.
#
# Q: What is the significance of the neural tube's closure?
# A: Proper closure of the neural tube is crucial to prevent birth defects such as spina bifida.
#
# Q: How does the neural tube close during development?
# A: The neural tube closes from the middle outwards, with anterior and posterior neuropores that must close.
#
# Q: What are the different forms of spina bifida?
# A: Spina bifida can range from mild (occulta) to severe (myelomeningocele).
#
# Q: What role do signaling molecules play in neural development?
# A: Key signaling molecules (e.g., Wnt, BMPs, FGFs, Notch) guide the differentiation of neural cells.
#
# Q: What are the distinct regions of the spinal cord during development?
# A: The spinal cord develops distinct regions: floor plate (motor neurons) and alar plate (sensory neurons), separated by the sulcus limitans.
#
# Q: What are the three primary vesicles that arise from the neural tube?
# A: The three primary vesicles are prosencephalon, mesencephalon, and rhombencephalon.
#
# Q: What are the three layers of the meninges?
# A: The meninges consist of the dura mater (outer), arachnoid mater (middle), and pia mater (inner).
#
# Q: What clinical issues can affect the meninges?
# A: Clinical issues such as meningitis and bleeds can affect the meninges.
#
# Q: What are gyri and sulci in the context of the brain?
# A: Gyri and sulci are surface features of the brain that serve as anatomical landmarks for identifying functional areas.
#
# Q: What are the key lobes of the brain and their associated functions?
# A: The key lobes include frontal, parietal, temporal, and occipital lobes, each associated with specific functions.
#
# Q: What structures are included in the limbic system?
# A: The limbic system includes structures like the amygdala and hippocampus, which are involved in emotions and memory.
#
# Q: What is the function of the insula in the brain?
# A: The insula plays a role in various functions, including emotional processing.
#
# Q: Why is understanding the functional areas of the cortex important?
# A: Understanding these areas is crucial for diagnosing and treating neurological conditions.

# %%
import spacy

nlp = spacy.blank("en")


def text_to_csv(text, output_csv):
    doc = nlp(text)

    questions = []
    answers = []

    for line in text.splitlines():
        line = line.strip()

        if line.startswith("Q: "):
            questions.append(line[3:].strip())
        elif line.startswith("A: "):
            answers.append(line[3:].strip())

    # Daten in einen DataFrame übertragen und als CSV speichern
    df = pd.DataFrame({"Question": questions, "Answer": answers})
    df.to_csv(output_csv, index=False, header=False, encoding="utf-8")

    print(f"Bereinigte Flashcards erfolgreich in {output_csv} gespeichert!")


text_to_csv(cleaned_flashcards, "anki_flashcards_no_duplicates.csv")
# Out:
# Bereinigte Flashcards erfolgreich in anki_flashcards_no_duplicates.csv gespeichert!

# %% [markdown]
# Create podcast script lol!

# %%
system_prompt = """
Convert lecture transcripts into engaging, listener-friendly podcast scripts.

Your task is to transform the provided lecture transcripts into scripts suitable for podcast episodes. Ensure the content is engaging, cohesive, and caters to a podcast audience rather than a lecture audience. Adjust the tone, structure, and content to be more conversational and listener-friendly while preserving the core information.

# Steps

1. **Review the Transcript**: Carefully read through the lecture transcript to understand the key points and overall message.
2. **Identify Key Sections**: Break down the lecture into main concepts or sections that will become segments of the podcast.
3. **Simplify and Clarify**: Simplify complex ideas for clarity and brevity. Use accessible language that would suit a general audience.
4. **Add Transitions**: Include transitions to smoothly link podcast sections and maintain a narrative flow. These transitions are not music or sound effects, everything in this script has to be read out loud, so don't include anything that can't be spoken.

# Goal
Your end goal is to produce a script that sounds as if it were written for a lively, informative podcast episode rather than a formal lecture.

"""

user_prompt = """
I have a lecture transcript that I want to convert into an engaging podcast script. The podcast should be suitable for neuroscience students and should feel dynamic, conversational, and easy to follow. Please adapt the tone, structure, and content to be more listener-friendly, while keeping the core information intact.

Instructions:
1. **Adjust the tone** to be friendly, conversational, and relatable, making it accessible for students who may listen anywhere and learn as they go.
2. **Structure the content** into clear segments, each focusing on a key concept or takeaway, to ensure a cohesive narrative.
3. **Simplify complex terms** and use accessible language to make it easy for a general neuroscience audience to understand.
4. **Add transitions** to maintain a smooth flow between segments, enhancing the script’s narrative quality.

Here is the transcript for conversion:
{transcript}
"""

# %%
import re


def clean_transcript(text):
    # Entferne Timecodes im Format [00:00:00] oder (00:00)
    text = re.sub(r"\[\d{2}:\d{2}:\d{2}\]|\(\d{2}:\d{2}\)", "", text)
    return text


with open("/Users/kyle/GitHub/gpt-anki-card-creator/transcript1.txt", "r") as file:
    raw_text = file.read()
clean_text = clean_transcript(raw_text)

# %%
def create_podcast_script(text, system_prompt, user_prompt):
    system_prompt = system_prompt
    user_prompt = user_prompt.format(transcript=text)

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        temperature=0.5,
        max_tokens=16384,
    )

    script = response.choices[0].message.content
    return script


script = create_podcast_script(clean_text, system_prompt, user_prompt)
print(script)
# Out:
# **Podcast Episode Script: Understanding the Nervous System - From Spinal Cord to Brain Development**
#
# ---
#
# **[INTRO MUSIC FADES IN]**
#
# **Host:**
# Welcome back to another episode of "Neuroscience Unplugged," where we break down the fascinating world of the nervous system into bite-sized pieces! I’m your host, [Your Name], and today we’re diving deep into the intricacies of the spinal cord, sensory and motor neurons, and even a little bit about brain development. So, grab your notebooks, or just sit back and relax, because we’re about to make some complex concepts much more digestible!
#
# ---
#
# **[SEGMENT 1: The Basics of the Nervous System]**
#
# **Host:**
# Alright, let’s kick things off with the spinal cord. Picture this: your spinal cord is like a highway, where information travels in both directions. On one side, we have motor neurons sending signals from the brain to the body. Think of them as the delivery trucks, carrying instructions for movement and action.
#
# But here’s the twist! The cell body of these motor neurons can be located at different levels of the spinal cord, sending their axons down to exit the spinal cord through the spinal nerves. This is how your brain communicates with your muscles to make things happen, whether that’s throwing a ball or just wiggling your toes!
#
# ---
#
# **[TRANSITION MUSIC]**
#
# **Host:**
# Now, let’s shift gears and talk about sensory neurons, which are quite different from our motor friends.
#
# ---
#
# **[SEGMENT 2: Sensory Neurons and Their Unique Structure]**
#
# **Host:**
# Sensory neurons are like the scouts of the nervous system. They gather information from the body and send it back to the brain. Here’s where it gets interesting: the cell bodies of these sensory neurons are located in a structure called the dorsal root ganglion. Instead of having a bunch of dendrites like motor neurons, sensory neurons are known as pseudo-unipolar neurons.
#
# What does that mean? Well, they have one long neurite that splits into two branches. One branch gathers information from the body, while the other sends it to the spinal cord and eventually to the brain. So, if you touch something hot, these neurons are the first to alert your brain, "Hey, we need to move!"
#
# ---
#
# **[TRANSITION MUSIC]**
#
# **Host:**
# Now that we’ve got a handle on these neurons, let’s explore how they all fit into the bigger picture of the nervous system.
#
# ---
#
# **[SEGMENT 3: The Structure of the Spinal Cord]**
#
# **Host:**
# In the spinal cord, we have different regions where these neurons reside. The motor neurons hang out in the ventral horn, while the sensory neurons chill in the dorsal horn. But there’s more! On the side, we have the lateral horn, which contains sympathetic neurons that play a role in the autonomic nervous system.
#
# These sympathetic neurons send their axons to ganglia, where they synapse onto other neurons that then communicate with target organs. It’s like a relay race, where each runner passes the baton until the message reaches its final destination—your organs!
#
# ---
#
# **[TRANSITION MUSIC]**
#
# **Host:**
# Speaking of destinations, let’s take a quick detour into the fascinating world of brain development!
#
# ---
#
# **[SEGMENT 4: Brain Development 101]**
#
# **Host:**
# During embryonic development, our nervous system originates from a layer of cells called the ectoderm. Around week three to four of development, the neural plate starts to fold up, creating what we call the neural tube. This tube will eventually develop into the spinal cord and brain.
#
# Now, if this tube doesn’t close properly, it can lead to some serious birth defects. For instance, if the front part doesn’t close, it can result in conditions that severely affect brain development. On the flip side, if the back part doesn’t close, we might see spina bifida, which comes in various severity levels.
#
# The good news? Taking folic acid before and during pregnancy can significantly reduce these risks!
#
# ---
#
# **[TRANSITION MUSIC]**
#
# **Host:**
# Alright, let’s wrap up our episode today by diving a bit deeper into the anatomy of the brain itself.
#
# ---
#
# **[SEGMENT 5: Brain Anatomy Overview]**
#
# **Host:**
# The brain is a complex structure made up of various regions, each responsible for different functions. We have the cerebrum, cerebellum, and brainstem, to name a few. Each part plays a crucial role in how we think, move, and interact with the world.
#
# For example, the cerebellum helps coordinate our movements, while the cerebral cortex is where higher-level thinking happens. And don’t forget about the limbic system, which is essential for emotions and memory.
#
# As we continue to explore the brain, we’ll also look at the protective layers surrounding it, known as the meninges. They play a vital role in safeguarding our brain from injury and infection.
#
# ---
#
# **[OUTRO MUSIC FADES IN]**
#
# **Host:**
# And that’s a wrap for today’s episode of "Neuroscience Unplugged!" I hope you enjoyed this journey through the nervous system, from the spinal cord to the brain. Remember, understanding these concepts is key to mastering neuroscience.
#
# Join us next time as we dive deeper into brain anatomy and functions. Don’t forget to subscribe and share this podcast with your fellow neuroscience enthusiasts! Until next time, keep your minds curious and your neurons firing.
#
# **[OUTRO MUSIC FADES OUT]**

# %%
with open("/Users/kyle/GitHub/gpt-anki-card-creator/podcast_script.txt", "w") as file:
    file.write(script)
